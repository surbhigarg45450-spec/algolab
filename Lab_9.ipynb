# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhigarg45450-spec/algolab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)
        if min_node is None:
          break

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
def displayShortest(result, stNode):
    for node in result:
        if result[node] == float('inf'):
            print(f"Distance from {stNode} to {node} = ∞")
        else:
            print(f"Distance from {stNode} to {node} = {result[node]}")

graph2 = {}

n = int(input("Enter number of nodes :"))

for i in range(n):
  node = input(f"Enter name of Node {i+1} : ")
  graph2[node] = {}
  edge = int(input(f"Enter Number of Edges from {node} : "))
  for j in range(edge):
    dest = input(f"Enter Destination Node {j+1} : ")
    weight = int(input(f"Enter weight to {dest} : "))
    graph2[node][dest] = weight

print("\n---------From A-----------")
result2 = dijkstra(graph2, 'A')
displayShortest(result2, 'A')

graph2['X'] = {'B':4, 'D':6}
graph2['Y'] = {'A':2, 'X':3}

print("\nFrom Different Sources : ")
for node in graph2:
  print(f"\n---------From {node}-----------")
  result2 = dijkstra(graph2, node)
  displayShortest(result2, node)
# Out:
# Enter number of nodes :4
# Enter name of Node 1 : A
# Enter Number of Edges from A : 2
# Enter Destination Node 1 : B
# Enter weight to B : 4
# Enter Destination Node 2 : C
# Enter weight to C : 2
# Enter name of Node 2 : B
# Enter Number of Edges from B : 3
# Enter Destination Node 1 : A
# Enter weight to A : 4
# Enter Destination Node 2 : C
# Enter weight to C : 5
# Enter Destination Node 3 : D
# Enter weight to D : 10
# Enter name of Node 3 : C
# Enter Number of Edges from C : 3
# Enter Destination Node 1 : A
# Enter weight to A : 2
# Enter Destination Node 2 : B
# Enter weight to B : 5
# Enter Destination Node 3 : D
# Enter weight to D : 3
# Enter name of Node 4 : D
# Enter Number of Edges from D : 2
# Enter Destination Node 1 : B
# Enter weight to B : 10
# Enter Destination Node 2 : C
# Enter weight to C : 3
#
# ---------From A-----------
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
#
# From Different Sources :
#
# ---------From A-----------
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5
# Distance from A to X = ∞
# Distance from A to Y = ∞
#
# ---------From B-----------
# Distance from B to A = 4
# Distance from B to B = 0
# Distance from B to C = 5
# Distance from B to D = 8
# Distance from B to X = ∞
# Distance from B to Y = ∞
#
# ---------From C-----------
# Distance from C to A = 2
# Distance from C to B = 5
# Distance from C to C = 0
# Distance from C to D = 3
# Distance from C to X = ∞
# Distance from C to Y = ∞
#
# ---------From D-----------
# Distance from D to A = 5
# Distance from D to B = 8
# Distance from D to C = 3
# Distance from D to D = 0
# Distance from D to X = ∞
# Distance from D to Y = ∞
#
# ---------From X-----------
# Distance from X to A = 8
# Distance from X to B = 4
# Distance from X to C = 9
# Distance from X to D = 6
# Distance from X to X = 0
# Distance from X to Y = ∞
#
# ---------From Y-----------
# Distance from Y to A = 2
# Distance from Y to B = 6
# Distance from Y to C = 4
# Distance from Y to D = 7
# Distance from Y to X = 3
# Distance from Y to Y = 0
