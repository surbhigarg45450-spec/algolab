# %% [markdown]
# <a href="https://colab.research.google.com/github/surbhigarg45450-spec/algolab/blob/main/Lab_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Travelling Salesman Problem using Dynamic Programming.
# Problem Description:
# Given a set of cities and distances, find the shortest possible route that visits each city once and returns to the starting city.

# %% [markdown]
# #Theory
# TSP uses dynamic programming with bit masking. Store results of visited subsets to reduce repeated work.
#
# ## Algorithm
# 1. Start from source city
# 2. Mark visited cities using bit mask
# 3. Try all unvisited cities
# 4. Choose minimum cost path
# 5. Return to source city

# %%
def tsp(graph):
    n = len(graph)
    dp = [[-1]*(1<<n) for _ in range(n)]
    p = [[-1]*(1<<n) for _ in range (n)]

    def visit(city, mask):
        if mask == (1<<n) - 1:
            return graph[city][0]

        if dp[city][mask] != -1:
            return dp[city][mask]

        ans = float('inf')
        best_next = -1

        for next_city in range(n):
            if mask & (1<<next_city) == 0:
                new_cost = graph[city][next_city] + visit(next_city, mask | (1<<next_city))
                if new_cost < ans:
                    ans = new_cost
                    best_next = next_city

        dp[city][mask] = ans
        p[city][mask] = best_next
        return ans

    min_cost = visit(0, 1)
    path = [0]
    mask = 1
    city = 0

    while True:
      next_city = p[city][mask]
      if next_city ==-1:
        break
      path.append(next_city)
      mask |= (1<<next_city)
      city = next_city
    path.append(0)

    return min_cost, path

# %%
graph = [
[0, 10, 15, 20],
[10, 0, 35, 25],
[15, 35, 0, 30],
[20, 25, 30, 0]
]

cost, path = tsp(graph)
print("Minimum travelling cost:", cost)
# Out:
# Minimum travelling cost: 80

# %% [markdown]
# # Exercise
# 1. Print path of cities visited
# 2. Take graph input from user
# 3. Test with different number of cities

# %%
print("Path is :", path)

graph2 = []
n = int(input("\nEnter Number of Nodes :"))
for i in range(n):
  ll = []

  print(f"\nFrom Node {i+1}")
  for j in range(n):
    if i==j:
      ll.append(0)
    else:
      c = int(input(f"Enter cost to Node {j+1} :"))
      ll.append(c)
  graph2.append(ll)

cost2, path2 = tsp(graph2)
print("\nMinimum cost is : ", cost2)
print("Path is : ", path2)
# Out:
# Path is : [0, 1, 3, 2, 0]
#
# Enter Number of Nodes :3
#
# From Node 1
# Enter cost to Node 2 :10
# Enter cost to Node 3 :15
#
# From Node 2
# Enter cost to Node 1 :10
# Enter cost to Node 3 :35
#
# From Node 3
# Enter cost to Node 1 :15
# Enter cost to Node 2 :35
#
# Minimum cost is :  60
# Path is :  [0, 1, 2, 0]
